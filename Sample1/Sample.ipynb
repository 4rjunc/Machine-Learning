# %%
import pandas as pd
import matplotlib.pyplot as plt

dict = {'DATE':[31-1-2020,29-2-2020,20-3-2020,31-4-2020,30-5-2020],
        'PRICE':[10000,7000,20000,8000,9000],
        'PRODUCT_ID':[901,902,903,904,905],
        'QUANTITY_PURCHASED':[34,37,56,60,50],
        'SERIAL_NO':[101,102,103,104,105],
        'USR_ID':[1001,1002,1003,1004,1005],
        'USR_TYPE':['A','B','C','A','B'],
        'USR_CLASS':['UPR','UPR','MDL','LWR','MDL'],
        'PUR_WEEK':['MON','TUE','WED','MON','WED']
}

df = pd.DataFrame(dict)
df.to_csv("df.csv")
print(df.head())

#GITITG

print(df)

#Prints all statistical values describe method
stats = df.describe(include='all')
print(stats)
df.plot(x = "USR_ID", y="PRICE", kind="line")
plt.show()
df[['QUANTITY_PURCHASED','PUR_WEEK']].plot.box()
plt.title('Quantity and Week value distribution')
plt.show()
# Out:
#    DATE  PRICE  PRODUCT_ID  QUANTITY_PURCHASED  SERIAL_NO  USR_ID USR_TYPE  \
# 0 -1990  10000         901                  34        101    1001        A
# 1 -1993   7000         902                  37        102    1002        B
# 2 -2003  20000         903                  56        103    1003        C
# 3 -1993   8000         904                  60        104    1004        A
# 4 -1995   9000         905                  50        105    1005        B
#
#   USR_CLASS PUR_WEEK
# 0       UPR      MON
# 1       UPR      TUE
# 2       MDL      WED
# 3       LWR      MON
# 4       MDL      WED
#    DATE  PRICE  PRODUCT_ID  QUANTITY_PURCHASED  SERIAL_NO  USR_ID USR_TYPE  \
# 0 -1990  10000         901                  34        101    1001        A
# 1 -1993   7000         902                  37        102    1002        B
# 2 -2003  20000         903                  56        103    1003        C
# 3 -1993   8000         904                  60        104    1004        A
# 4 -1995   9000         905                  50        105    1005        B
#
#   USR_CLASS PUR_WEEK
# 0       UPR      MON
# 1       UPR      TUE
# 2       MDL      WED
# 3       LWR      MON
# 4       MDL      WED
#               DATE         PRICE  PRODUCT_ID  QUANTITY_PURCHASED   SERIAL_NO  \
# count      5.00000      5.000000    5.000000            5.000000    5.000000
# unique         NaN           NaN         NaN                 NaN         NaN
# top            NaN           NaN         NaN                 NaN         NaN
# freq           NaN           NaN         NaN                 NaN         NaN
# mean   -1994.80000  10800.000000  903.000000           47.400000  103.000000
# std        4.91935   5263.078947    1.581139           11.480418    1.581139
# min    -2003.00000   7000.000000  901.000000           34.000000  101.000000
# 25%    -1995.00000   8000.000000  902.000000           37.000000  102.000000
# 50%    -1993.00000   9000.000000  903.000000           50.000000  103.000000
# 75%    -1993.00000  10000.000000  904.000000           56.000000  104.000000
# max    -1990.00000  20000.000000  905.000000           60.000000  105.000000
#
#              USR_ID USR_TYPE USR_CLASS PUR_WEEK
# count      5.000000        5         5        5
# unique          NaN        3         3        3
# top             NaN        A       UPR      MON
# freq            NaN        2         2        2
# mean    1003.000000      NaN       NaN      NaN
# std        1.581139      NaN       NaN      NaN
# min     1001.000000      NaN       NaN      NaN
# 25%     1002.000000      NaN       NaN      NaN
# 50%     1003.000000      NaN       NaN      NaN
# 75%     1004.000000      NaN       NaN      NaN
# max     1005.000000      NaN       NaN      NaN
